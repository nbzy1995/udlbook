# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-szmejyjz
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-szmejyjz
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from mnist1d==0.0.2.post9) (2.32.3)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from mnist1d==0.0.2.post9) (1.26.4)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (from mnist1d==0.0.2.post9) (3.9.0)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.10/site-packages (from mnist1d==0.0.2.post9) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post9) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post9) (24.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post9) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->mnist1d==0.0.2.post9) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests->mnist1d==0.0.2.post9) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303343, train error 90.18,  test loss 2.303858, test error 89.90
# Epoch   100, train loss 1.903901, train error 72.90,  test loss 1.756873, test error 70.85
# Epoch   200, train loss 1.891021, train error 71.05,  test loss 1.732066, test error 68.75
# Epoch   300, train loss 1.892883, train error 70.82,  test loss 1.733972, test error 69.43
# Epoch   400, train loss 1.888028, train error 70.38,  test loss 1.721660, test error 68.60
# Epoch   500, train loss 1.887836, train error 70.40,  test loss 1.722266, test error 68.95
# Epoch   600, train loss 1.886316, train error 70.62,  test loss 1.724108, test error 69.03
# Epoch   700, train loss 1.888640, train error 70.93,  test loss 1.727638, test error 68.53
# Epoch   800, train loss 1.888558, train error 70.97,  test loss 1.718596, test error 69.25
# Epoch   900, train loss 1.886307, train error 70.72,  test loss 1.724937, test error 69.40
# Training model with   4 hidden variables
# Epoch     0, train loss 2.279066, train error 88.90,  test loss 2.276727, test error 88.57
# Epoch   100, train loss 1.779945, train error 65.10,  test loss 1.609002, test error 63.45
# Epoch   200, train loss 1.766696, train error 64.90,  test loss 1.608725, test error 63.15
# Epoch   300, train loss 1.760045, train error 64.95,  test loss 1.620457, test error 64.60
# Epoch   400, train loss 1.752096, train error 64.43,  test loss 1.610420, test error 63.40
# Epoch   500, train loss 1.749449, train error 64.43,  test loss 1.606647, test error 63.62
# Epoch   600, train loss 1.746423, train error 63.92,  test loss 1.609383, test error 62.72
# Epoch   700, train loss 1.744647, train error 64.15,  test loss 1.603311, test error 63.17
# Epoch   800, train loss 1.753448, train error 64.60,  test loss 1.620659, test error 63.53
# Epoch   900, train loss 1.744339, train error 64.15,  test loss 1.623620, test error 63.55
# Training model with   6 hidden variables
# Epoch     0, train loss 2.244144, train error 85.53,  test loss 2.239269, test error 85.47
# Epoch   100, train loss 1.673091, train error 60.38,  test loss 1.502492, test error 59.90
# Epoch   200, train loss 1.637406, train error 59.35,  test loss 1.485204, test error 58.38
# Epoch   300, train loss 1.623321, train error 59.20,  test loss 1.483334, test error 57.83
# Epoch   400, train loss 1.609028, train error 58.53,  test loss 1.479771, test error 57.55
# Epoch   500, train loss 1.598210, train error 58.38,  test loss 1.477557, test error 58.15
# Epoch   600, train loss 1.601375, train error 58.40,  test loss 1.487842, test error 57.75
# Epoch   700, train loss 1.592020, train error 58.30,  test loss 1.488916, test error 57.50
# Epoch   800, train loss 1.592320, train error 58.03,  test loss 1.485417, test error 57.53
# Epoch   900, train loss 1.596009, train error 58.50,  test loss 1.486449, test error 56.40
# Training model with   8 hidden variables
# Epoch     0, train loss 2.220112, train error 84.90,  test loss 2.213297, test error 84.90
# Epoch   100, train loss 1.637776, train error 57.95,  test loss 1.516278, test error 58.30
# Epoch   200, train loss 1.590757, train error 56.67,  test loss 1.479098, test error 57.62
# Epoch   300, train loss 1.564504, train error 55.30,  test loss 1.469431, test error 57.70
# Epoch   400, train loss 1.551194, train error 55.15,  test loss 1.452723, test error 55.97
# Epoch   500, train loss 1.543117, train error 54.97,  test loss 1.465155, test error 56.38
# Epoch   600, train loss 1.538259, train error 54.88,  test loss 1.463344, test error 55.80
# Epoch   700, train loss 1.527378, train error 54.28,  test loss 1.466965, test error 56.25
# Epoch   800, train loss 1.523901, train error 53.78,  test loss 1.471294, test error 56.40
# Epoch   900, train loss 1.528215, train error 53.58,  test loss 1.494192, test error 57.40
# Training model with  10 hidden variables
# Epoch     0, train loss 2.211531, train error 83.75,  test loss 2.183026, test error 82.40
# Epoch   100, train loss 1.525768, train error 51.62,  test loss 1.378390, test error 51.40
# Epoch   200, train loss 1.451417, train error 48.70,  test loss 1.347445, test error 50.03
# Epoch   300, train loss 1.415951, train error 47.50,  test loss 1.323326, test error 49.25
# Epoch   400, train loss 1.398839, train error 47.10,  test loss 1.319845, test error 48.45
# Epoch   500, train loss 1.393563, train error 47.03,  test loss 1.328820, test error 47.85
# Epoch   600, train loss 1.380126, train error 46.97,  test loss 1.318376, test error 47.50
# Epoch   700, train loss 1.370844, train error 46.53,  test loss 1.332043, test error 47.38
# Epoch   800, train loss 1.358502, train error 46.08,  test loss 1.347752, test error 47.67
# Epoch   900, train loss 1.356898, train error 46.65,  test loss 1.368234, test error 47.42
# Training model with  14 hidden variables
# Epoch     0, train loss 2.212712, train error 81.60,  test loss 2.190434, test error 80.28
# Epoch   100, train loss 1.416762, train error 48.42,  test loss 1.299989, test error 48.85
# Epoch   200, train loss 1.331596, train error 45.17,  test loss 1.257193, test error 46.70
# Epoch   300, train loss 1.307170, train error 44.42,  test loss 1.295524, test error 47.70
# Epoch   400, train loss 1.285475, train error 43.60,  test loss 1.294682, test error 47.28
# Epoch   500, train loss 1.291845, train error 43.83,  test loss 1.327803, test error 49.00
# Epoch   600, train loss 1.269082, train error 43.35,  test loss 1.327322, test error 47.53
# Epoch   700, train loss 1.260936, train error 42.83,  test loss 1.322941, test error 47.42
# Epoch   800, train loss 1.262904, train error 43.25,  test loss 1.338686, test error 47.92
# Epoch   900, train loss 1.247903, train error 42.75,  test loss 1.352401, test error 47.85
# Training model with  18 hidden variables
# Epoch     0, train loss 2.260553, train error 85.18,  test loss 2.255350, test error 84.72
# Epoch   100, train loss 1.331835, train error 44.25,  test loss 1.290618, test error 48.38
# Epoch   200, train loss 1.216428, train error 38.80,  test loss 1.267938, test error 47.03
# Epoch   300, train loss 1.168751, train error 38.53,  test loss 1.312509, test error 47.50
# Epoch   400, train loss 1.144528, train error 38.12,  test loss 1.361719, test error 47.62
# Epoch   500, train loss 1.128932, train error 37.38,  test loss 1.396472, test error 48.30
# Epoch   600, train loss 1.115455, train error 36.95,  test loss 1.416769, test error 48.17
# Epoch   700, train loss 1.108091, train error 36.72,  test loss 1.442233, test error 49.10
# Epoch   800, train loss 1.100898, train error 36.78,  test loss 1.474005, test error 48.80
# Epoch   900, train loss 1.096574, train error 36.42,  test loss 1.472492, test error 49.10
# Training model with  22 hidden variables
# Epoch     0, train loss 2.148204, train error 80.25,  test loss 2.099527, test error 77.68
# Epoch   100, train loss 1.373198, train error 47.08,  test loss 1.393604, test error 51.72
# Epoch   200, train loss 1.202774, train error 40.30,  test loss 1.381286, test error 50.10
# Epoch   300, train loss 1.136511, train error 37.80,  test loss 1.438021, test error 50.53
# Epoch   400, train loss 1.112469, train error 37.22,  test loss 1.495508, test error 51.90
# Epoch   500, train loss 1.085570, train error 36.40,  test loss 1.533302, test error 51.92
# Epoch   600, train loss 1.072116, train error 36.38,  test loss 1.612915, test error 53.33
# Epoch   700, train loss 1.046224, train error 35.50,  test loss 1.670028, test error 53.55
# Epoch   800, train loss 1.030363, train error 34.78,  test loss 1.752727, test error 54.08
# Epoch   900, train loss 1.020228, train error 34.22,  test loss 1.783932, test error 53.85
# Training model with  26 hidden variables
# Epoch     0, train loss 2.265730, train error 83.60,  test loss 2.259606, test error 82.95
# Epoch   100, train loss 1.152666, train error 36.28,  test loss 1.263717, test error 46.42
# Epoch   200, train loss 1.025921, train error 32.82,  test loss 1.376504, test error 49.35
# Epoch   300, train loss 0.959452, train error 31.60,  test loss 1.481846, test error 50.05
# Epoch   400, train loss 0.920943, train error 31.25,  test loss 1.597575, test error 51.67
# Epoch   500, train loss 0.879564, train error 29.40,  test loss 1.656217, test error 51.58
# Epoch   600, train loss 0.858726, train error 28.50,  test loss 1.738657, test error 51.97
# Epoch   700, train loss 0.848521, train error 29.07,  test loss 1.784799, test error 52.28
# Epoch   800, train loss 0.835742, train error 28.57,  test loss 1.857572, test error 52.10
# Epoch   900, train loss 0.814266, train error 27.68,  test loss 1.930174, test error 53.17
# Training model with  30 hidden variables
# Epoch     0, train loss 2.139795, train error 79.00,  test loss 2.102881, test error 80.10
# Epoch   100, train loss 1.115363, train error 36.83,  test loss 1.381698, test error 50.17
# Epoch   200, train loss 0.949660, train error 30.97,  test loss 1.529414, test error 51.30
# Epoch   300, train loss 0.872066, train error 28.25,  test loss 1.688394, test error 53.03
# Epoch   400, train loss 0.811386, train error 27.07,  test loss 1.831435, test error 53.15
# Epoch   500, train loss 0.767007, train error 25.68,  test loss 2.012570, test error 54.03
# Epoch   600, train loss 0.736913, train error 24.38,  test loss 2.114774, test error 53.22
# Epoch   700, train loss 0.714787, train error 23.80,  test loss 2.276816, test error 54.55
# Epoch   800, train loss 0.690383, train error 23.28,  test loss 2.337658, test error 54.95
# Epoch   900, train loss 0.679240, train error 23.03,  test loss 2.476575, test error 55.53
# Training model with  35 hidden variables
# Epoch     0, train loss 2.091026, train error 78.05,  test loss 2.060263, test error 79.43
# Epoch   100, train loss 1.018229, train error 32.40,  test loss 1.366980, test error 48.42
# Epoch   200, train loss 0.803362, train error 25.60,  test loss 1.638286, test error 50.78
# Epoch   300, train loss 0.674317, train error 21.20,  test loss 2.036673, test error 53.53
# Epoch   400, train loss 0.598156, train error 19.47,  test loss 2.465667, test error 54.40
# Epoch   500, train loss 0.527254, train error 16.80,  test loss 2.828196, test error 55.88
# Epoch   600, train loss 0.492305, train error 16.45,  test loss 3.248480, test error 56.38
# Epoch   700, train loss 0.473301, train error 16.30,  test loss 3.623889, test error 57.00
# Epoch   800, train loss 0.464329, train error 16.70,  test loss 4.000930, test error 57.58
# Epoch   900, train loss 0.454747, train error 16.22,  test loss 4.273335, test error 56.95
# Training model with  40 hidden variables
# Epoch     0, train loss 2.075673, train error 78.00,  test loss 2.010593, test error 77.22
# Epoch   100, train loss 0.931108, train error 29.65,  test loss 1.461578, test error 50.92
# Epoch   200, train loss 0.670808, train error 21.55,  test loss 1.947298, test error 52.15
# Epoch   300, train loss 0.496821, train error 15.20,  test loss 2.486316, test error 54.05
# Epoch   400, train loss 0.402862, train error 12.55,  test loss 3.204196, test error 55.10
# Epoch   500, train loss 0.341167, train error 10.55,  test loss 3.932930, test error 55.58
# Epoch   600, train loss 0.285488, train error 9.32,  test loss 4.775054, test error 56.58
# Epoch   700, train loss 0.283048, train error 9.85,  test loss 5.655957, test error 55.88
# Epoch   800, train loss 0.281070, train error 9.50,  test loss 6.431494, test error 56.60
# Epoch   900, train loss 0.235642, train error 8.18,  test loss 6.920029, test error 58.08
# Training model with  45 hidden variables
# Epoch     0, train loss 2.075232, train error 77.10,  test loss 2.040553, test error 78.38
# Epoch   100, train loss 0.817074, train error 26.35,  test loss 1.527859, test error 51.60
# Epoch   200, train loss 0.485633, train error 16.30,  test loss 2.316841, test error 53.92
# Epoch   300, train loss 0.299815, train error 9.75,  test loss 3.382031, test error 54.10
# Epoch   400, train loss 0.212677, train error 6.80,  test loss 4.720094, test error 55.85
# Epoch   500, train loss 0.100013, train error 2.28,  test loss 6.006766, test error 56.12
# Epoch   600, train loss 0.143070, train error 5.00,  test loss 7.335483, test error 56.42
# Epoch   700, train loss 0.010873, train error 0.00,  test loss 8.223029, test error 55.75
# Epoch   800, train loss 0.007228, train error 0.00,  test loss 8.815132, test error 55.72
# Epoch   900, train loss 0.005477, train error 0.00,  test loss 9.268979, test error 55.78
# Training model with  50 hidden variables
# Epoch     0, train loss 2.063527, train error 76.60,  test loss 2.001916, test error 76.95
# Epoch   100, train loss 0.684010, train error 21.30,  test loss 1.653884, test error 51.58
# Epoch   200, train loss 0.342358, train error 10.70,  test loss 2.731467, test error 54.20
# Epoch   300, train loss 0.156462, train error 4.03,  test loss 4.266698, test error 54.83
# Epoch   400, train loss 0.024191, train error 0.00,  test loss 5.741334, test error 55.53
# Epoch   500, train loss 0.011903, train error 0.00,  test loss 6.627091, test error 55.80
# Epoch   600, train loss 0.007713, train error 0.00,  test loss 7.215954, test error 55.70
# Epoch   700, train loss 0.005529, train error 0.00,  test loss 7.649477, test error 55.85
# Epoch   800, train loss 0.004321, train error 0.00,  test loss 8.000269, test error 55.50
# Epoch   900, train loss 0.003489, train error 0.00,  test loss 8.290546, test error 55.65
# Training model with  55 hidden variables
# Epoch     0, train loss 2.044865, train error 75.12,  test loss 1.982021, test error 73.12
# Epoch   100, train loss 0.638515, train error 20.15,  test loss 1.659730, test error 50.75
# Epoch   200, train loss 0.233651, train error 5.55,  test loss 2.967163, test error 53.35
# Epoch   300, train loss 0.050093, train error 0.05,  test loss 4.580054, test error 54.00
# Epoch   400, train loss 0.016037, train error 0.00,  test loss 5.614340, test error 54.40
# Epoch   500, train loss 0.009219, train error 0.00,  test loss 6.240736, test error 54.28
# Epoch   600, train loss 0.006267, train error 0.00,  test loss 6.693650, test error 54.10
# Epoch   700, train loss 0.004620, train error 0.00,  test loss 7.045618, test error 54.20
# Epoch   800, train loss 0.003635, train error 0.00,  test loss 7.331465, test error 54.17
# Epoch   900, train loss 0.002972, train error 0.00,  test loss 7.569610, test error 54.17
# Training model with  60 hidden variables
# Epoch     0, train loss 2.058170, train error 75.35,  test loss 2.031650, test error 76.97
# Epoch   100, train loss 0.538046, train error 15.32,  test loss 1.775540, test error 53.08
# Epoch   200, train loss 0.133860, train error 2.47,  test loss 3.386079, test error 55.97
# Epoch   300, train loss 0.021472, train error 0.00,  test loss 4.834648, test error 57.00
# Epoch   400, train loss 0.009882, train error 0.00,  test loss 5.551382, test error 56.70
# Epoch   500, train loss 0.006179, train error 0.00,  test loss 6.021612, test error 56.85
# Epoch   600, train loss 0.004408, train error 0.00,  test loss 6.365131, test error 57.00
# Epoch   700, train loss 0.003381, train error 0.00,  test loss 6.642388, test error 56.85
# Epoch   800, train loss 0.002736, train error 0.00,  test loss 6.873657, test error 56.80
# Epoch   900, train loss 0.002264, train error 0.00,  test loss 7.063735, test error 56.70
# Training model with  70 hidden variables
# Epoch     0, train loss 2.066163, train error 75.12,  test loss 2.042789, test error 77.07
# Epoch   100, train loss 0.353967, train error 8.75,  test loss 1.908298, test error 50.62
# Epoch   200, train loss 0.030669, train error 0.03,  test loss 3.428829, test error 51.67
# Epoch   300, train loss 0.010403, train error 0.00,  test loss 4.155258, test error 52.00
# Epoch   400, train loss 0.005956, train error 0.00,  test loss 4.573051, test error 52.05
# Epoch   500, train loss 0.003998, train error 0.00,  test loss 4.850862, test error 51.95
# Epoch   600, train loss 0.002974, train error 0.00,  test loss 5.067700, test error 52.08
# Epoch   700, train loss 0.002334, train error 0.00,  test loss 5.240939, test error 52.05
# Epoch   800, train loss 0.001914, train error 0.00,  test loss 5.386004, test error 51.95
# Epoch   900, train loss 0.001608, train error 0.00,  test loss 5.512234, test error 52.00
# Training model with  80 hidden variables
# Epoch     0, train loss 2.058261, train error 76.38,  test loss 2.008384, test error 76.25
# Epoch   100, train loss 0.224108, train error 3.57,  test loss 2.010917, test error 51.20
# Epoch   200, train loss 0.019844, train error 0.00,  test loss 3.305936, test error 52.10
# Epoch   300, train loss 0.007971, train error 0.00,  test loss 3.836029, test error 52.35
# Epoch   400, train loss 0.004714, train error 0.00,  test loss 4.157115, test error 52.53
# Epoch   500, train loss 0.003273, train error 0.00,  test loss 4.378699, test error 52.88
# Epoch   600, train loss 0.002460, train error 0.00,  test loss 4.555553, test error 52.92
# Epoch   700, train loss 0.001956, train error 0.00,  test loss 4.698514, test error 52.85
# Epoch   800, train loss 0.001613, train error 0.00,  test loss 4.820961, test error 52.97
# Epoch   900, train loss 0.001366, train error 0.00,  test loss 4.924634, test error 52.95
# Training model with  90 hidden variables
# Epoch     0, train loss 2.030596, train error 74.82,  test loss 1.981086, test error 75.00
# Epoch   100, train loss 0.131036, train error 0.75,  test loss 2.184884, test error 51.10
# Epoch   200, train loss 0.014577, train error 0.00,  test loss 3.190132, test error 51.00
# Epoch   300, train loss 0.006505, train error 0.00,  test loss 3.616839, test error 51.28
# Epoch   400, train loss 0.003968, train error 0.00,  test loss 3.881623, test error 51.25
# Epoch   500, train loss 0.002791, train error 0.00,  test loss 4.069458, test error 51.28
# Epoch   600, train loss 0.002121, train error 0.00,  test loss 4.219532, test error 51.30
# Epoch   700, train loss 0.001696, train error 0.00,  test loss 4.339957, test error 51.20
# Epoch   800, train loss 0.001403, train error 0.00,  test loss 4.443974, test error 51.03
# Epoch   900, train loss 0.001191, train error 0.00,  test loss 4.533589, test error 51.22
# Training model with 100 hidden variables
# Epoch     0, train loss 1.992255, train error 73.68,  test loss 1.918936, test error 73.78
# Epoch   100, train loss 0.098046, train error 0.28,  test loss 2.206426, test error 51.40
# Epoch   200, train loss 0.013050, train error 0.00,  test loss 3.097964, test error 51.88
# Epoch   300, train loss 0.005925, train error 0.00,  test loss 3.470375, test error 52.08
# Epoch   400, train loss 0.003682, train error 0.00,  test loss 3.701656, test error 52.05
# Epoch   500, train loss 0.002609, train error 0.00,  test loss 3.870653, test error 52.03
# Epoch   600, train loss 0.001994, train error 0.00,  test loss 4.004299, test error 52.10
# Epoch   700, train loss 0.001600, train error 0.00,  test loss 4.114594, test error 52.15
# Epoch   800, train loss 0.001328, train error 0.00,  test loss 4.207256, test error 52.28
# Epoch   900, train loss 0.001130, train error 0.00,  test loss 4.286434, test error 52.10
# Training model with 120 hidden variables
# Epoch     0, train loss 1.963438, train error 72.80,  test loss 1.905091, test error 74.03
# Epoch   100, train loss 0.049059, train error 0.00,  test loss 2.281717, test error 51.12
# Epoch   200, train loss 0.009353, train error 0.00,  test loss 2.918472, test error 51.15
# Epoch   300, train loss 0.004629, train error 0.00,  test loss 3.210799, test error 51.03
# Epoch   400, train loss 0.002954, train error 0.00,  test loss 3.393999, test error 51.10
# Epoch   500, train loss 0.002133, train error 0.00,  test loss 3.530427, test error 50.97
# Epoch   600, train loss 0.001651, train error 0.00,  test loss 3.637753, test error 51.08
# Epoch   700, train loss 0.001336, train error 0.00,  test loss 3.726717, test error 51.10
# Epoch   800, train loss 0.001116, train error 0.00,  test loss 3.802364, test error 51.22
# Epoch   900, train loss 0.000954, train error 0.00,  test loss 3.869791, test error 51.15
# Training model with 140 hidden variables
# Epoch     0, train loss 1.965635, train error 72.47,  test loss 1.908367, test error 72.18
# Epoch   100, train loss 0.036986, train error 0.00,  test loss 2.196162, test error 50.28
# Epoch   200, train loss 0.008063, train error 0.00,  test loss 2.686339, test error 49.67
# Epoch   300, train loss 0.004133, train error 0.00,  test loss 2.921872, test error 49.83
# Epoch   400, train loss 0.002680, train error 0.00,  test loss 3.075822, test error 49.60
# Epoch   500, train loss 0.001951, train error 0.00,  test loss 3.190371, test error 49.70
# Epoch   600, train loss 0.001515, train error 0.00,  test loss 3.281242, test error 49.78
# Epoch   700, train loss 0.001230, train error 0.00,  test loss 3.356180, test error 49.78
# Epoch   800, train loss 0.001030, train error 0.00,  test loss 3.420523, test error 49.70
# Epoch   900, train loss 0.000883, train error 0.00,  test loss 3.475801, test error 49.67
# Training model with 160 hidden variables
# Epoch     0, train loss 1.948049, train error 71.82,  test loss 1.884799, test error 72.53
# Epoch   100, train loss 0.028220, train error 0.00,  test loss 2.115135, test error 49.25
# Epoch   200, train loss 0.007227, train error 0.00,  test loss 2.519659, test error 49.45
# Epoch   300, train loss 0.003791, train error 0.00,  test loss 2.716580, test error 49.28
# Epoch   400, train loss 0.002494, train error 0.00,  test loss 2.849054, test error 49.12
# Epoch   500, train loss 0.001826, train error 0.00,  test loss 2.947657, test error 49.30
# Epoch   600, train loss 0.001427, train error 0.00,  test loss 3.026192, test error 49.30
# Epoch   700, train loss 0.001162, train error 0.00,  test loss 3.092232, test error 49.28
# Epoch   800, train loss 0.000976, train error 0.00,  test loss 3.148293, test error 49.45
# Epoch   900, train loss 0.000837, train error 0.00,  test loss 3.196871, test error 49.50
# Training model with 180 hidden variables
# Epoch     0, train loss 1.918533, train error 70.82,  test loss 1.845344, test error 72.72
# Epoch   100, train loss 0.024271, train error 0.00,  test loss 2.080298, test error 48.78
# Epoch   200, train loss 0.006531, train error 0.00,  test loss 2.427188, test error 48.55
# Epoch   300, train loss 0.003502, train error 0.00,  test loss 2.598926, test error 48.20
# Epoch   400, train loss 0.002320, train error 0.00,  test loss 2.715827, test error 48.25
# Epoch   500, train loss 0.001708, train error 0.00,  test loss 2.802930, test error 48.20
# Epoch   600, train loss 0.001338, train error 0.00,  test loss 2.873762, test error 48.15
# Epoch   700, train loss 0.001092, train error 0.00,  test loss 2.931303, test error 48.25
# Epoch   800, train loss 0.000919, train error 0.00,  test loss 2.980906, test error 48.25
# Epoch   900, train loss 0.000790, train error 0.00,  test loss 3.024662, test error 48.17
# Training model with 200 hidden variables
# Epoch     0, train loss 1.907036, train error 69.88,  test loss 1.854246, test error 72.90
# Epoch   100, train loss 0.021720, train error 0.00,  test loss 2.066792, test error 48.70
# Epoch   200, train loss 0.006229, train error 0.00,  test loss 2.396014, test error 48.60
# Epoch   300, train loss 0.003379, train error 0.00,  test loss 2.564064, test error 48.22
# Epoch   400, train loss 0.002244, train error 0.00,  test loss 2.677117, test error 48.17
# Epoch   500, train loss 0.001656, train error 0.00,  test loss 2.764428, test error 48.22
# Epoch   600, train loss 0.001299, train error 0.00,  test loss 2.831973, test error 48.15
# Epoch   700, train loss 0.001062, train error 0.00,  test loss 2.889922, test error 48.22
# Epoch   800, train loss 0.000893, train error 0.00,  test loss 2.938734, test error 48.20
# Epoch   900, train loss 0.000768, train error 0.00,  test loss 2.981584, test error 48.17
# Training model with 250 hidden variables
# Epoch     0, train loss 1.896953, train error 69.55,  test loss 1.838948, test error 71.72
# Epoch   100, train loss 0.017367, train error 0.00,  test loss 1.914893, test error 48.70
# Epoch   200, train loss 0.005443, train error 0.00,  test loss 2.162027, test error 48.47
# Epoch   300, train loss 0.003014, train error 0.00,  test loss 2.293663, test error 48.40
# Epoch   400, train loss 0.002032, train error 0.00,  test loss 2.383585, test error 48.15
# Epoch   500, train loss 0.001511, train error 0.00,  test loss 2.453059, test error 48.03
# Epoch   600, train loss 0.001192, train error 0.00,  test loss 2.508120, test error 47.95
# Epoch   700, train loss 0.000978, train error 0.00,  test loss 2.554963, test error 48.00
# Epoch   800, train loss 0.000826, train error 0.00,  test loss 2.594716, test error 48.00
# Epoch   900, train loss 0.000712, train error 0.00,  test loss 2.629971, test error 47.88
# Training model with 300 hidden variables
# Epoch     0, train loss 1.856339, train error 66.50,  test loss 1.790152, test error 69.32
# Epoch   100, train loss 0.014146, train error 0.00,  test loss 1.856056, test error 45.75
# Epoch   200, train loss 0.004739, train error 0.00,  test loss 2.070909, test error 45.72
# Epoch   300, train loss 0.002692, train error 0.00,  test loss 2.189115, test error 45.80
# Epoch   400, train loss 0.001835, train error 0.00,  test loss 2.269582, test error 45.95
# Epoch   500, train loss 0.001374, train error 0.00,  test loss 2.331975, test error 45.97
# Epoch   600, train loss 0.001089, train error 0.00,  test loss 2.382546, test error 45.92
# Epoch   700, train loss 0.000896, train error 0.00,  test loss 2.424998, test error 45.88
# Epoch   800, train loss 0.000759, train error 0.00,  test loss 2.461367, test error 45.90
# Epoch   900, train loss 0.000656, train error 0.00,  test loss 2.493040, test error 46.00
# Training model with 400 hidden variables
# Epoch     0, train loss 1.847616, train error 67.10,  test loss 1.804921, test error 69.35
# Epoch   100, train loss 0.011782, train error 0.00,  test loss 1.751380, test error 45.62
# Epoch   200, train loss 0.004205, train error 0.00,  test loss 1.921281, test error 45.15
# Epoch   300, train loss 0.002432, train error 0.00,  test loss 2.013912, test error 44.80
# Epoch   400, train loss 0.001675, train error 0.00,  test loss 2.078479, test error 44.75
# Epoch   500, train loss 0.001263, train error 0.00,  test loss 2.128233, test error 44.80
# Epoch   600, train loss 0.001005, train error 0.00,  test loss 2.169189, test error 44.70
# Epoch   700, train loss 0.000831, train error 0.00,  test loss 2.203740, test error 44.62
# Epoch   800, train loss 0.000705, train error 0.00,  test loss 2.233246, test error 44.62
# Epoch   900, train loss 0.000611, train error 0.00,  test loss 2.259451, test error 44.55

# %%
# Plot the results
fig, ax = plt.subplots()
ax.set_xscale('log')
ax.plot(hidden_variables**2, errors_train_all,'r-',label='train')
ax.plot(hidden_variables**2, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('Num params'); ax.set_ylabel('Error')
ax.legend()
plt.show()
